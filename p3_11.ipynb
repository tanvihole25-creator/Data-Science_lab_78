# %% [markdown]
# <a href="https://colab.research.google.com/github/tanvihole25-creator/Data-Science_lab_78/blob/main/p3_11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
a = np.array([[1, 2, 3],
              [4, 5, 6]])
a.shape
# Out:
# (2, 3)

# %%
a = np.array([1, 2, 3, 4, 5, 6])
a
# Out:
# array([1, 2, 3, 4, 5, 6])

# %%
a = np.array([[2,4,5,6], [12,13,14,15], [9, 10, 11, 18]])
a
# Out:
# array([[ 2,  4,  5,  6],
#        [12, 13, 14, 15],
#        [ 9, 10, 11, 18]])

# %%
a[0]
# Out:
# np.int64(1)

# %%
a[0] = 10
a
# Out:
# array([10,  2,  3,  4,  5,  6])

# %%
a[:3]
# Out:
# array([10,  2,  3])

# %%
b = a[4:]
b
b[0] = 10
a
# Out:
# array([10,  2,  3,  4, 10,  6])

# %%
a = np.array([[2,4,5,6], [12,13,14,15], [9, 10, 11, 18]])
a
# Out:
# array([[ 2,  4,  5,  6],
#        [12, 13, 14, 15],
#        [ 9, 10, 11, 18]])

# %%
a[1, 3]
# Out:
# np.int64(15)

# %%
a.ndim
# Out:
# 2

# %%
a.shape
len(a.shape) == a.ndim
# Out:
# True

# %%
a.size
import math
a.size == math.prod(a.shape)
# Out:
# True

# %%
a.dtype
# Out:
# dtype('int64')

# %%
np.zeros(5)
# Out:
# array([0., 0., 0., 0., 0.])

# %%
np.ones(3)
# Out:
# array([1., 1., 1.])

# %%
# Create an empty array with 2 elements
np.empty(2)
# Out:
# array([4.94065646e-324, 6.55116354e-310])

# %%
np.arange(6)
# Out:
# array([0, 1, 2, 3, 4, 5])

# %%
np.arange(2, 9, 2)
# Out:
# array([2, 4, 6, 8])

# %%
np.linspace(0, 10, num=5)
# Out:
# array([ 0. ,  2.5,  5. ,  7.5, 10. ])

# %%
x = np.ones(2, dtype=np.int64)
x
# Out:
# array([1, 1])

# %%
x = np.ones(2, dtype=np.int64)
x
# Out:
# array([1, 1])

# %%
a = np.array([1, 2, 3, 4])
b = np.array([5, 6, 7, 8])

# %%
np.reshape(a, shape=(1, 6), order='C')

# %%
np.concatenate((a, b))
# Out:
# array([1, 2, 3, 4, 5, 6, 7, 8])

# %%
x = np.array([[1, 2], [3, 4]])
y = np.array([[5, 6]])
np.concatenate((x, y), axis=0)
# Out:
# array([[1, 2],
#        [3, 4],
#        [5, 6]])

# %%
array_example = np.array([[[0, 1, 2, 3],
                           [4, 5, 6, 7]],
                          [[0, 1, 2, 3],
                           [4, 5, 6, 7]],
                          [[0 ,1 ,2, 3],
                           [4, 5, 6, 7]]])
array_example.ndim
# Out:
# 3

# %%
array_example.size
# Out:
# 24

# %%
array_example.shape
# Out:
# (3, 2, 4)

# %%
a = np.arange(6)
print(a)
# Out:
# [0 1 2 3 4 5]

# %%
a = np.array([1, 2, 3, 4, 5, 6])
a.shape
# Out:
# (6,)

# %%
row_vector = a[np.newaxis, :]
row_vector.shape
# Out:
# (1, 6)

# %%
col_vector = a[:, np.newaxis]
col_vector.shape
# Out:
# (6, 1)

# %%
data = np.array([1, 2, 3])

data[1]
data[0:2]
data[1:]
data[-2:]
# Out:
# array([2, 3])
